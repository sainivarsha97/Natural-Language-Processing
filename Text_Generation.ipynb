# %%
'''Import required libraries'''

import string
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from nltk.tokenize import word_tokenize
# Out:
# Using TensorFlow backend.

# %%
'''optional step'''
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ce4a08ee-cef9-4a7c-b43c-d9a910674ad3" name="files[]" multiple disabled />
#      <output id="result-ce4a08ee-cef9-4a7c-b43c-d9a910674ad3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving war.txt to war.txt

# %%
'''opening a file'''

file = open('war.txt', 'r',encoding="ISO-8859-1")
text=file.read()
file.close()

# %%
text
# Out:
# '"Well, Prince, so Genoa and Lucca are now just family estates of the\nBuonapartes. But I warn you, if you don\'t tell me that this means war,\nif you still try to defend the infamies and horrors perpetrated by that\nAntichrist--I really believe he is Antichrist--I will have nothing more\nto do with you and you are no longer my friend, no longer my \'faithful\nslave,\' as you call yourself! But how do you do? I see I have frightened\nyou--sit down and tell me all the news."\n\nIt was in July, 1805, and the speaker was the well-known Anna Pavlovna\nScherer, maid of honor and favorite of the Empress Marya Fedorovna. With\nthese words she greeted Prince Vasili Kuragin, a man of high rank and\nimportance, who was the first to arrive at her reception. Anna Pavlovna\nhad had a cough for some days. She was, as she said, suffering from la\ngrippe; grippe being then a new word in St. Petersburg, used only by the\nelite.\n\nAll her invitations without exception, written in French, and delivered\nby a scarlet-liveried footman that morning, ran as follows:\n\n"If you have nothing better to do, Count (or Prince), and if the\nprospect of spending an evening with a poor invalid is not too terrible,\nI shall be very charmed to see you tonight between 7 and 10--Annette\nScherer."\n\n"Heavens! what a virulent attack!" replied the prince, not in the least\ndisconcerted by this reception. He had just entered, wearing an\nembroidered court uniform, knee breeches, and shoes, and had stars on\nhis breast and a serene expression on his flat face. He spoke in that\nrefined French in which our grandfathers not only spoke but thought, and\nwith the gentle, patronizing intonation natural to a man of importance\nwho had grown old in society and at court. He went up to Anna Pavlovna,\nkissed her hand, presenting to her his bald, scented, and shining head,\nand complacently seated himself on the sofa.\n\n"First of all, dear friend, tell me how you are. Set your friend\'s mind\nat rest," said he without altering his tone, beneath the politeness and\naffected sympathy of which indifference and even irony could be\ndiscerned.\n\n"Can one be well while suffering morally? Can one be calm in times like\nthese if one has any feeling?" said Anna Pavlovna. "You are staying the\nwhole evening, I hope?"\n\n"And the fete at the English ambassador\'s? Today is Wednesday. I must\nput in an appearance there," said the prince. "My daughter is coming for\nme to take me there."\n\n"I thought today\'s fete had been canceled. I confess all these\nfestivities and fireworks are becoming wearisome."\n\n"If they had known that you wished it, the entertainment would have been\nput off," said the prince, who, like a wound-up clock, by force of habit\nsaid things he did not even wish to be believed.\n\n"Don\'t tease! Well, and what has been decided about Novosiltsev\'s\ndispatch? You know everything."\n\n"What can one say about it?" replied the prince in a cold, listless\ntone. "What has been decided? They have decided that Buonaparte has\nburnt his boats, and I believe that we are ready to burn ours."\n\nPrince Vasili always spoke languidly, like an actor repeating a stale\npart. Anna Pavlovna Scherer on the contrary, despite her forty years,\noverflowed with animation and impulsiveness. To be an enthusiast had\nbecome her social vocation and, sometimes even when she did not feel\nlike it, she became enthusiastic in order not to disappoint the\nexpectations of those who knew her. The subdued smile which, though it\ndid not suit her faded features, always played round her lips expressed,\nas in a spoiled child, a continual consciousness of her charming defect,\nwhich she neither wished, nor could, nor considered it necessary, to\ncorrect.\n\nIn the midst of a conversation on political matters Anna Pavlovna burst\nout:\n\n"Oh, don\'t speak to me of Austria. Perhaps I don\'t understand things,\nbut Austria never has wished, and does not wish, for war. She is\nbetraying us! Russia alone ...

# %%
def clean_doc(doc):
    '''this function is used to clean the data'''
    
    clean_words= []

    words = word_tokenize(text)
    for word in words:
        word = word.strip(string.punctuation)
        if len(word)>=1 and word.isdigit()==False:
                word = word.lower()
                clean_words.append(word)
    return clean_words

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
token=clean_doc(text)
token[0]
# Out:
# 'well'

# %%
'''creating sequence of length 21'''

sequence_len=21
seq=[]
for i in range(0,len(token)-sequence_len):
    seq.append(token[i:i+sequence_len])

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(seq) 
tokenizer

# %%
'''gving a numerical value for each token'''
sequence = tokenizer.texts_to_sequences(seq) 
sequence[0]
# Out:
# [249,
#  26,
#  47,
#  1096,
#  2,
#  1095,
#  52,
#  84,
#  67,
#  157,
#  1093,
#  4,
#  1,
#  1091,
#  29,
#  10,
#  1089,
#  9,
#  44,
#  9,
#  31]

# %%
'''check the index no of each token'''
tokenizer.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'to': 3,
#  'of': 4,
#  'a': 5,
#  'her': 6,
#  'in': 7,
#  'he': 8,
#  'you': 9,
#  'i': 10,
#  'that': 11,
#  'she': 12,
#  'was': 13,
#  'is': 14,
#  'with': 15,
#  'as': 16,
#  'had': 17,
#  'anna': 18,
#  'pavlovna': 19,
#  'it': 20,
#  'said': 21,
#  'not': 22,
#  'have': 23,
#  'his': 24,
#  's': 25,
#  'prince': 26,
#  'at': 27,
#  'this': 28,
#  'but': 29,
#  'for': 30,
#  'do': 31,
#  'be': 32,
#  'who': 33,
#  'on': 34,
#  'one': 35,
#  'him': 36,
#  'all': 37,
#  'has': 38,
#  'an': 39,
#  'me': 40,
#  'very': 41,
#  'what': 42,
#  'know': 43,
#  'if': 44,
#  'by': 45,
#  'will': 46,
#  'so': 47,
#  "n't": 48,
#  'been': 49,
#  'they': 50,
#  'young': 51,
#  'are': 52,
#  'my': 53,
#  'man': 54,
#  'only': 55,
#  'or': 56,
#  'which': 57,
#  'did': 58,
#  'about': 59,
#  'little': 60,
#  'princess': 61,
#  'vasili': 62,
#  'your': 63,
#  'round': 64,
#  'them': 65,
#  'aunt': 66,
#  'just': 67,
#  'there': 68,
#  'can': 69,
#  'like': 70,
#  'though': 71,
#  'were': 72,
#  'empress': 73,
#  'first': 74,
#  'from': 75,
#  'our': 76,
#  'old': 77,
#  'up': 78,
#  'always': 79,
#  'out': 80,
#  'added': 81,
#  'abbe': 82,
#  'pierre': 83,
#  'now': 84,
#  'nothing': 85,
#  'more': 86,
#  'how': 87,
#  'face': 88,
#  'himself': 89,
#  'wished': 90,
#  'would': 91,
#  'when': 92,
#  'smile': 93,
#  'speak': 94,
#  'than': 95,
#  'drawing': 96,
#  'something': 97,
#  'room': 98,
#  'each': 99,
#  'tell': 100,
#  'no': 101,
#  'these': 102,
#  'reception': 103,
#  'french': 104,
#  'too': 105,
#  'expression': 106,
#  'tone': 107,
#  'could': 108,
#  'daughter': 109,
#  'we': 110,
#  'conversation': 111,
#  'good': 112,
#  'think': 113,
#  'mortemart': 114,
#  'baron': 115,
#  'son': 116,
#  'time': 117,
#  'come': 118,
#  'father': 119,
#  'another': 120,
#  'woman': 121,
#  'health': 122,
#  'group': 123,
#  'own': 124,
#  'down': 125,
#  'maid': 126,
#  'some': 127,
#  'being': 128,
#  'word': 129,
#  'petersburg': 130,
#  'without': 131,
#  'evening': 132,
#  'poor': 133,
#  'shall': 134,
#  'spoke': 135,
#  'thought': 136,
#  'society': 137,
#  'any': 138,
#  'say': 139,
#  'whom': 140,
#  'emperor': 141,
#  'get': 142,
#  'am': 143,
#  'interesting': 144,
#  'men': 145,
#  'vicomte': 146,
#  'morio': 147,
#  'came': 148,
#  'beautiful': 149,
#  'continued': 150,
#  'life': 151,
#  'children': 152,
#  'anatole': 153,
#  'bolkonskaya': 154,
#  'clever': 155,
#  'dress': 156,
#  'family': 157,
#  'war': 158,
#  'still': 159,
#  'believe': 160,
#  'friend': 161,
#  'see': 162,
#  'well-known': 163,
#  'scherer': 164,
#  'honor': 165,
#  'words': 166,
#  'high': 167,
#  'la': 168,
#  'then': 169,
#  'tonight': 170,
#  'between': 171,
#  'annette': 172,
#  'replied': 173,
#  'natural': 174,
#  'went': 175,
#  'hand': 176,
#  'head': 177,
#  'dear': 178,
#  'set': 179,
#  'politeness': 180,
#  'even': 181,
#  'whole': 182,
#  'today': 183,
#  'must': 184,
#  'put': 185,
#  'becoming': 186,
#  'decided': 187,
#  'become': 188,
#  'social': 189,
#  'vocation': 190,
#  'knew': 191,
#  'charming': 192,
#  'nor': 193,
#  'understand': 194,
#  'alone': 195,
#  'europe': 196,
#  'god': 197,
#  'prussia': 198,
#  'suddenly': 199,
#  'smiling': 200,
#  'again': 201,
#  'two': 202,
#  'also': 203,
#  'profound': 204,
#  'heard': 205,
#  'dowager': 206,
#  'funke': 207,
#  'anyone': 208,
#  'else': 209,
#  'mentioned': 210,
#  'majesty': 211,
#  'show': 212,
#  'silent': 213,
#  'looked': 214,
#  'same': 215,
#  'everyone': 216,
#  'after': 217,
#  'short': 218,
#  'such': 219,
#  'last': 220,
#  'turned': 221,
#  'way': 222,
#  'yet': 223,
#  'rich': 224,
#  'lise': 225,
#  'here': 226,
#  'listen': 227,
#  'most': 228,
#  'people': 229,
#  'helene': 230,
#  'large': 231,
#  'lady': 232,
#  'guests': 233,
#  'began': 234,
#  'turning': 235,
#  'visitor': 236,
#  'left': 237,
#  'work': 238,
#  'pretty': 239,
#  'lip': 240,
#  'full': 241,
#  'hostess': 242,
#  'waiting': 243,
#  'look': 244,
#  'anxiety': 245,
#  'rather': 246,
#  'away': 247,
#  'buonaparte': 248,
#  'well': 249,
#  'antichrist': 250,
#  'really': 251,
#  'longer': 252,
#  'faithful': 253,
#  'slave': 254,
#  'marya': 255,
#  'fedorovna': 256,
#  'greeted': 257,
#  'importance': 258,
#  'arrive': 259,
#  'suffering': 260,
#  'grippe': 261,
#  'new': 262,
#  'exception': 263,
#  'better': 264,
#  'count': 265,
#  'invalid': 266,
#  'terrible': 267,
#  'least': 268,
#  'entered': 269,
#  'wearing': 270,
#  'embroidered': 271,
#  'court': 272,
#  'breeches': 273,
#  'breast': 274,
#  'refined': 275,
#  'kissed': 276,
#  'sofa': 277,
#  'mind': 278,
#  'while': 279,
#  'calm': 280,
#  'hope': 281,
#  'fete': 282,
#  'english': 283,
#  'ambassador': 284,
#  'appearance': 285,
#  'take': 286,
#  'confess': 287,
#  'known': 288,
#  'entertainment': 289,
#  'things': 290,
#  'wish': 291,
#  'ready': 292,
#  'forty': 293,
#  'years': 294,
#  'sometimes': 295,
#  'feel': 296,
#  'order': 297,
#  'those': 298,
#  'features': 299,
#  'played': 300,
#  'lips': 301,
#  'expressed': 302,
#  'child': 303,
#  'defect': 304,
#  'neither': 305,
#  'considered': 306,
#  'political': 307,
#  'austria': 308,
#  'perhaps': 309,
#  'never': 310,
#  'russia': 311,
#  'save': 312,
#  'sovereign': 313,
#  'true': 314,
#  'thing': 315,
#  'faith': 316,
#  'perform': 317,
#  'person': 318,
#  'ask': 319,
#  'wanted': 320,
#  'motive': 321,
#  'answer': 322,
#  'wants': 323,
#  'promised': 324,
#  'before': 325,
#  'either': 326,
#  'king': 327,
#  'expecting': 328,
#  'de': 329,
#  'through': 330,
#  'ones': 331,
#  'meet': 332,
#  'occurred': 333,
#  'visit': 334,
#  'others': 335,
#  'eyes': 336,
#  'pleased': 337,
#  'recommended': 338,
#  'mournful': 339,
#  'assumed': 340,
#  'respect': 341,
#  'sadness': 342,
#  'over': 343,
#  'quickness': 344,
#  'both': 345,
#  'bowed': 346,
#  'often': 347,
#  'pause': 348,
#  'intimate': 349,
#  'why': 350,
#  'fate': 351,
#  'ca': 352,
#  'help': 353,
#  'talk': 354,
#  'reply': 355,
#  'their': 356,
#  'hippolyte': 357,
#  'mouth': 358,
#  'looking': 359,
#  'myself': 360,
#  'unhappy': 361,
#  'yours': 362,
#  'evidently': 363,
#  'check': 364,
#  'goes': 365,
#  'bolkonski': 366,
#  'married': 367,
#  "pavlovna's": 368,
#  'peculiar': 369,
#  'lay': 370,
#  'll': 371,
#  'age': 372,
#  'circle': 373,
#  'small': 374,
#  'seen': 375,
#  'conducted': 376,
#  'ribbon': 377,
#  'soon': 378,
#  'performed': 379,
#  'greeting': 380,
#  'cared': 381,
#  'having': 382,
#  'brought': 383,
#  'bag': 384,
#  'upper': 385,
#  'teeth': 386,
#  'seemed': 387,
#  'sight': 388,
#  'company': 389,
#  'saw': 390,
#  'specially': 391,
#  'sat': 392,
#  'doing': 393,
#  'addressing': 394,
#  'present': 395,
#  'spread': 396,
#  'stout': 397,
#  'abroad': 398,
#  'where': 399,
#  'educated': 400,
#  'place': 401,
#  'hear': 402,
#  'duties': 403,
#  'watch': 404,
#  'machine': 405,
#  'proper': 406,
#  'motion': 407,
#  'kept': 408,
#  'gathered': 409,
#  'choice': 410,
#  'duc': 411,
#  "d'enghien": 412,
#  'reasons': 413,
#  'means': 414,
#  'try': 415,
#  'defend': 416,
#  'infamies': 417,
#  'horrors': 418,
#  'perpetrated': 419,
#  'call': 420,
#  'yourself': 421,
#  'frightened': 422,
#  'sit': 423,
#  'news': 424,
#  'july': 425,
#  'speaker': 426,
#  'favorite': 427,
#  'kuragin': 428,
#  'rank': 429,
#  'cough': 430,
#  'days': 431,
#  'st': 432,
#  'used': 433,
#  'elite': 434,
#  'invitations': 435,
#  'written': 436,
#  'delivered': 437,
#  'scarlet-liveried': 438,
#  'footman': 439,
#  'morning': 440,
#  'ran': 441,
#  'follows': 442,
#  'prospect': 443,
#  'spending': 444,
#  'charmed': 445,
#  'heavens': 446,
#  'virulent': 447,
#  'attack': 448,
#  'disconcerted': 449,
#  'uniform': 450,
#  'knee': 451,
#  'shoes': 452,
#  'stars': 453,
#  'serene': 454,
#  'flat': 455,
#  'grandfathers': 456,
#  'gentle': 457,
#  'patronizing': 458,
#  'intonation': 459,
#  'grown': 460,
#  'presenting': 461,
#  'bald': 462,
#  'scented': 463,
#  'shining': 464,
#  'complacently': 465,
#  'seated': 466,
#  'rest': 467,
#  'altering': 468,
#  'beneath': 469,
#  'affected': 470,
#  'sympathy': 471,
#  'indifference': 472,
#  'irony': 473,
#  'discerned': 474,
#  'morally': 475,
#  'times': 476,
#  'feeling': 477,
#  'staying': 478,
#  'wednesday': 479,
#  'coming': 480,
#  'canceled': 481,
#  'festivities': 482,
#  'fireworks': 483,
#  'wearisome': 484,
#  'off': 485,
#  'wound-up': 486,
#  'clock': 487,
#  'force': 488,
#  'habit': 489,
#  'believed': 490,
#  'tease': 491,
#  "novosiltsev's": 492,
#  'dispatch': 493,
#  'everything': 494,
#  'cold': 495,
#  'listless': 496,
#  'burnt': 497,
#  'boats': 498,
#  'burn': 499,
#  'ours': 500,
#  'languidly': 501,
#  'actor': 502,
#  'repeating': 503,
#  'stale': 504,
#  'part': 505,
#  'contrary': 506,
#  'despite': 507,
#  'overflowed': 508,
#  'animation': 509,
#  'impulsiveness': 510,
#  'enthusiast': 511,
#  'became': 512,
#  'enthusiastic': 513,
#  'disappoint': 514,
#  'expectations': 515,
#  'subdued': 516,
#  'suit': 517,
#  'faded': 518,
#  'spoiled': 519,
#  'continual': 520,
#  'consciousness': 521,
#  'necessary': 522,
#  'correct': 523,
#  'midst': 524,
#  'matters': 525,
#  'burst': 526,
#  'oh': 527,
#  'does': 528,
#  'betraying': 529,
#  'us': 530,
#  'gracious': 531,
#  'recognizes': 532,
#  'wonderful': 533,
#  'noblest': 534,
#  'role': 535,
#  'earth': 536,
#  'virtuous': 537,
#  'noble': 538,
#  'forsake': 539,
#  'fulfill': 540,
#  'crush': 541,
#  'hydra': 542,
#  'revolution': 543,
#  'ever': 544,
#  'murderer': 545,
#  'villain': 546,
#  'avenge': 547,
#  'blood': 548,
#  'rely': 549,
#  'england': 550,
#  'commercial': 551,
#  'spirit': 552,
#  'alexander': 553,
#  'loftiness': 554,
#  'soul': 555,
#  'refused': 556,
#  'evacuate': 557,
#  'malta': 558,
#  'find': 559,
#  'seeks': 560,
#  'secret': 561,
#  'actions': 562,
#  'novosiltsev': 563,
#  'none': 564,
#  'understood': 565,
#  'self-abnegation': 566,
#  'desires': 567,
#  'mankind': 568,
#  'declared': 569,
#  'invincible': 570,
#  'powerless': 571,
#  'hardenburg': 572,
#  'says': 573,
#  'haugwitz': 574,
#  'famous': 575,
#  'prussian': 576,
#  'neutrality': 577,
#  'trap': 578,
#  'lofty': 579,
#  'destiny': 580,
#  'adored': 581,
#  'monarch': 582,
#  'paused': 583,
#  'impetuosity': 584,
#  'sent': 585,
#  'instead': 586,
#  'wintzingerode': 587,
#  'captured': 588,
#  'consent': 589,
#  'assault': 590,
#  'eloquent': 591,
#  'give': 592,
#  'cup': 593,
#  'tea': 594,
#  'moment': 595,
#  'propos': 596,
#  'le': 597,
#  'connected': 598,
#  'montmorencys': 599,
#  'rohans': 600,
#  'best': 601,
#  'families': 602,
#  'genuine': 603,
#  'emigres': 604,
#  'thinker': 605,
#  'received': 606,
#  'delighted': 607,
#  'studied': 608,
#  'carelessness': 609,
#  'question': 610,
#  'chief': 611,
#  'appointed': 612,
#  'secretary': 613,
#  'vienna': 614,
#  'accounts': 615,
#  'creature': 616,
#  'obtain': 617,
#  'post': 618,
#  'trying': 619,
#  'secure': 620,
#  'almost': 621,
#  'closed': 622,
#  'indicate': 623,
#  'right': 624,
#  'criticize': 625,
#  'desired': 626,
#  'sister': 627,
#  'dry': 628,
#  'named': 629,
#  'sincere': 630,
#  'devotion': 631,
#  'mingled': 632,
#  'every': 633,
#  'illustrious': 634,
#  'patroness': 635,
#  'deigned': 636,
#  'beaucoup': 637,
#  "d'estime": 638,
#  'clouded': 639,
#  'indifferent': 640,
#  'womanly': 641,
#  'courtierlike': 642,
#  'tact': 643,
#  'habitual': 644,
#  'rebuke': 645,
#  'daring': 646,
#  'done': 647,
#  'console': 648,
#  'since': 649,
#  'enraptured': 650,
#  'amazingly': 651,
#  'signify': 652,
#  'gratitude': 653,
#  'nearer': 654,
#  'amiably': 655,
#  'topics': 656,
#  'ended': 657,
#  'unfairly': 658,
#  'joys': 659,
#  'distributed': 660,
#  'given': 661,
#  'splendid': 662,
#  "don't": 663,
#  'youngest': 664,
#  'admitting': 665,
#  'rejoinder': 666,
#  'raising': 667,
#  'eyebrows': 668,
#  'appreciate': 669,
#  'less': 670,
#  'deserve': 671,
#  'smiled': 672,
#  'ecstatic': 673,
#  'lavater': 674,
#  'lack': 675,
#  'bump': 676,
#  'paternity': 677,
#  'joke': 678,
#  'mean': 679,
#  'serious': 680,
#  'dissatisfied': 681,
#  'younger': 682,
#  'ourselves': 683,
#  'its': 684,
#  'melancholy': 685,
#  "majesty's": 686,
#  'pitied': 687,
#  'answered': 688,
#  'significantly': 689,
#  'awaiting': 690,
#  'frowned': 691,
#  'education': 692,
#  'fools': 693,
#  'quiet': 694,
#  'fool': 695,
#  'active': 696,
#  'difference': 697,
#  'animated': 698,
#  'usual': 699,
#  'wrinkles': 700,
#  'clearly': 701,
#  'revealed': 702,
#  'unexpectedly': 703,
#  'coarse': 704,
#  'unpleasant': 705,
#  'born': 706,
#  'reproach': 707,
#  'pensively': 708,
#  'bane': 709,
#  'cross': 710,
#  'bear': 711,
#  'explain': 712,
#  'helped': 713,
#  'resignation': 714,
#  'cruel': 715,
#  'gesture': 716,
#  'meditated': 717,
#  'marrying': 718,
#  'prodigal': 719,
#  'asked': 720,
#  'maids': 721,
#  'mania': 722,
#  'matchmaking': 723,
#  'weakness': 724,
#  'relation': 725,
#  'mary': 726,
#  'memory': 727,
#  'perception': 728,
#  'befitting': 729,
#  'world': 730,
#  'indicated': 731,
#  'movement': 732,
#  'considering': 733,
#  'information': 734,
#  'unable': 735,
#  'sad': 736,
#  'current': 737,
#  'thoughts': 738,
#  'costing': 739,
#  'thousand': 740,
#  'rubles': 741,
#  'year': 742,
#  'five': 743,
#  'presently': 744,
#  'fathers': 745,
#  'stingy': 746,
#  'lives': 747,
#  'country': 748,
#  'retire': 749,
#  'army': 750,
#  'under': 751,
#  'late': 752,
#  'nicknamed': 753,
#  'eccentric': 754,
#  'bore': 755,
#  'girl': 756,
#  'brother': 757,
#  'meinen': 758,
#  'lately': 759,
#  'aide-de-camp': 760,
#  'kutuzov': 761,
#  'taking': 762,
#  'reason': 763,
#  'downwards': 764,
#  'arrange': 765,
#  'affair': 766,
#  'devoted': 767,
#  'slave-slafe': 768,
#  'f': 769,
#  'village': 770,
#  'elder': 771,
#  'mine': 772,
#  'writes': 773,
#  'reports': 774,
#  'want': 775,
#  'familiarity': 776,
#  'easy': 777,
#  'grace': 778,
#  'raised': 779,
#  'swung': 780,
#  'fro': 781,
#  'back': 782,
#  'armchair': 783,
#  'direction': 784,
#  'attendez': 785,
#  'reflecting': 786,
#  'wife': 787,
#  'arranged': 788,
#  'behalf': 789,
#  'start': 790,
#  'apprenticeship': 791,
#  'gradually': 792,
#  'filling': 793,
#  'highest': 794,
#  'assembled': 795,
#  'differing': 796,
#  'widely': 797,
#  'character': 798,
#  'alike': 799,
#  'belonged': 800,
#  'wore': 801,
#  'ball': 802,
#  'badge': 803,
#  'youthful': 804,
#  'femme': 805,
#  'plus': 806,
#  'seduisante': 807,
#  'petersbourg': 808,
#  'during': 809,
#  'previous': 810,
#  'winter': 811,
#  'pregnant': 812,
#  'go': 813,
#  'gatherings': 814,
#  'receptions': 815,
#  'introduced': 816,
#  'many': 817,
#  'fascinating': 818,
#  'arrival': 819,
#  'gravely': 820,
#  'bows': 821,
#  'cap': 822,
#  'sailing': 823,
#  'slowly': 824,
#  'name': 825,
#  'ceremony': 826,
#  'observed': 827,
#  'greetings': 828,
#  'solemn': 829,
#  'interest': 830,
#  'approval': 831,
#  'thank': 832,
#  'prevented': 833,
#  'showing': 834,
#  'impatience': 835,
#  'sense': 836,
#  'relief': 837,
#  'vexatious': 838,
#  'duty': 839,
#  'return': 840,
#  'gold': 841,
#  'velvet': 842,
#  'delicate': 843,
#  'dark': 844,
#  'perceptible': 845,
#  'lifted': 846,
#  'sweetly': 847,
#  'especially': 848,
#  'occasionally': 849,
#  'drew': 850,
#  'lower': 851,
#  'case': 852,
#  'thoroughly': 853,
#  'attractive': 854,
#  'shortness': 855,
#  'half-open': 856,
#  'special': 857,
#  'form': 858,
#  'beauty': 859,
#  'brightened': 860,
#  'mother': 861,
#  'carrying': 862,
#  'burden': 863,
#  'lightly': 864,
#  'dull': 865,
#  'dispirited': 866,
#  'talking': 867,
#  'felt': 868,
#  'talked': 869,
#  'bright': 870,
#  'constant': 871,
#  'gleam': 872,
#  'white': 873,
#  'amiable': 874,
#  'mood': 875,
#  'day': 876,
#  'table': 877,
#  'quick': 878,
#  'swaying': 879,
#  'steps': 880,
#  'workbag': 881,
#  'arm': 882,
#  'gaily': 883,
#  'spreading': 884,
#  'near': 885,
#  'silver': 886,
#  'samovar': 887,
#  'pleasure': 888,
#  'herself': 889,
#  'around': 890,
#  'displaying': 891,
#  'wicked': 892,
#  'trick': 893,
#  'wrote': 894,
#  'quite': 895,
#  'badly': 896,
#  'dressed': 897,
#  'arms': 898,
#  'short-waisted': 899,
#  'lace-trimmed': 900,
#  'dainty': 901,
#  'gray': 902,
#  'girdled': 903,
#  'broad': 904,
#  'below': 905,
#  'soyez': 906,
#  'tranquille': 907,
#  'prettier': 908,
#  'voice': 909,
#  'general': 910,
#  'husband': 911,
#  'deserting': 912,
#  'going': 913,
#  'killed': 914,
#  'wretched': 915,
#  'delightful': 916,
#  'next': 917,
#  'arrivals': 918,
#  'heavily': 919,
#  'built': 920,
#  'close-cropped': 921,
#  'hair': 922,
#  'spectacles': 923,
#  'light-colored': 924,
#  'fashionable': 925,
#  'ruffle': 926,
#  'brown': 927,
#  'coat': 928,
#  'illegitimate': 929,
#  'bezukhov': 930,
#  'grandee': 931,
#  'catherine': 932,
#  'dying': 933,
#  'moscow': 934,
#  'military': 935,
#  'civil': 936,
#  'service': 937,
#  'returned': 938,
#  'nod': 939,
#  'accorded': 940,
#  'lowest': 941,
#  'hierarchy': 942,
#  'spite': 943,
#  'lowest-grade': 944,
#  'fear': 945,
#  'unsuited': 946,
#  'enter': 947,
#  'certainly': 948,
#  'bigger': 949,
#  'other': 950,
#  'reference': 951,
#  'shy': 952,
#  'observant': 953,
#  'distinguished': 954,
#  'monsieur': 955,
#  'exchanging': 956,
#  'alarmed': 957,
#  'glance': 958,
#  'murmured': 959,
#  'unintelligible': 960,
#  'search': 961,
#  'acquaintance': 962,
#  'alarm': 963,
#  'justified': 964,
#  'speech': 965,
#  'dismay': 966,
#  'detained': 967,
#  'yes': 968,
#  'scheme': 969,
#  'perpetual': 970,
#  'peace': 971,
#  'hardly': 972,
#  'feasible': 973,
#  'rejoined': 974,
#  'attend': 975,
#  'committed': 976,
#  'reverse': 977,
#  'act': 978,
#  'impoliteness': 979,
#  'finished': 980,
#  'speaking': 981,
#  'bent': 982,
#  'big': 983,
#  'feet': 984,
#  'apart': 985,
#  'explaining': 986,
#  'thinking': 987,
#  'plan': 988,
#  'chimerical': 989,
#  'later': 990,
#  'got': 991,
#  'rid': 992,
#  'behave': 993,
#  'resumed': 994,
#  'point': 995,
#  'might': 996,
#  'happen': 997,
#  'flag': 998,
#  'foreman': 999,
#  'spinning': 1000,
#  ...}

# %%
'''Total vocab size'''
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 1098

# %%
'''change to numpy array'''
import numpy as np
arr=np.array(sequence)

# %%
X, Y = arr[:,:-1], arr[:,-1]
Y.shape
# Out:
# (3650,)

# %%
Y=to_categorical(Y,num_classes=vocab_size) 
Y.shape
# Out:
# (3650, 1098)

# %%
seq_length = X.shape[1]

# %%
'''MODEL'''
#adding different layers to form model
from keras.models import Sequential
from keras.layers import Dense,LSTM,Embedding

model = Sequential()
model.add(Embedding(vocab_size, 150, input_length=seq_length))
model.add(LSTM(1024, return_sequences=True))
model.add(LSTM(1024))
model.add(Dense(1024, activation='relu'))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0902 11:30:47.727161 140086889686912 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0902 11:30:47.775994 140086889686912 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0902 11:30:47.784556 140086889686912 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 20, 150)           164700
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 20, 1024)          4812800
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1024)              8392704
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1098)              1125450
# =================================================================
# Total params: 15,545,254
# Trainable params: 15,545,254
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, batch_size=80, epochs=150)
# Out:
# W0902 11:30:54.477140 140086889686912 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0902 11:30:54.514919 140086889686912 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0902 11:30:54.690168 140086889686912 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0902 11:30:56.091707 140086889686912 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/150
# 3650/3650 [==============================] - 18s 5ms/step - loss: 6.4431 - acc: 0.0359
# Epoch 2/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 6.0429 - acc: 0.0414
# Epoch 3/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 6.0271 - acc: 0.0425
# Epoch 4/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 5.9677 - acc: 0.0367
# Epoch 5/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 5.9028 - acc: 0.0433
# Epoch 6/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 5.6954 - acc: 0.0477
# Epoch 7/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 5.4867 - acc: 0.0564
# Epoch 8/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 5.2234 - acc: 0.0627
# Epoch 9/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 5.0161 - acc: 0.0699
# Epoch 10/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 4.7952 - acc: 0.0742
# Epoch 11/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 4.5755 - acc: 0.0844
# Epoch 12/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 4.5199 - acc: 0.0923
# Epoch 13/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 4.1662 - acc: 0.1008
# Epoch 14/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.8333 - acc: 0.1334
# Epoch 15/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.5115 - acc: 0.1584
# Epoch 16/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.1357 - acc: 0.2107
# Epoch 17/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.7519 - acc: 0.2775
# Epoch 18/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.3139 - acc: 0.3759
# Epoch 19/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.8261 - acc: 0.4907
# Epoch 20/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.3760 - acc: 0.6195
# Epoch 21/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.9902 - acc: 0.7241
# Epoch 22/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.6036 - acc: 0.8570
# Epoch 23/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.3116 - acc: 0.9378
# Epoch 24/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.1272 - acc: 0.9855
# Epoch 25/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0471 - acc: 0.9975
# Epoch 26/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0222 - acc: 0.9992
# Epoch 27/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0123 - acc: 1.0000
# Epoch 28/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0091 - acc: 1.0000
# Epoch 29/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0075 - acc: 1.0000
# Epoch 30/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0063 - acc: 1.0000
# Epoch 31/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0055 - acc: 1.0000
# Epoch 32/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0048 - acc: 1.0000
# Epoch 33/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0043 - acc: 1.0000
# Epoch 34/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0038 - acc: 1.0000
# Epoch 35/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0034 - acc: 1.0000
# Epoch 36/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0031 - acc: 1.0000
# Epoch 37/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0028 - acc: 1.0000
# Epoch 38/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0025 - acc: 1.0000
# Epoch 39/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0023 - acc: 1.0000
# Epoch 40/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0021 - acc: 1.0000
# Epoch 41/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0019 - acc: 1.0000
# Epoch 42/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0018 - acc: 1.0000
# Epoch 43/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0016 - acc: 1.0000
# Epoch 44/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0015 - acc: 1.0000
# Epoch 45/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0014 - acc: 1.0000
# Epoch 46/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0013 - acc: 1.0000
# Epoch 47/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0012 - acc: 1.0000
# Epoch 48/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0011 - acc: 1.0000
# Epoch 49/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 0.0010 - acc: 1.0000
# Epoch 50/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 9.5313e-04 - acc: 1.0000
# Epoch 51/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 8.9108e-04 - acc: 1.0000
# Epoch 52/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 8.3036e-04 - acc: 1.0000
# Epoch 53/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 7.7835e-04 - acc: 1.0000
# Epoch 54/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 7.2859e-04 - acc: 1.0000
# Epoch 55/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 6.8222e-04 - acc: 1.0000
# Epoch 56/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 6.3978e-04 - acc: 1.0000
# Epoch 57/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 6.0089e-04 - acc: 1.0000
# Epoch 58/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 5.6491e-04 - acc: 1.0000
# Epoch 59/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 5.3223e-04 - acc: 1.0000
# Epoch 60/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 5.0080e-04 - acc: 1.0000
# Epoch 61/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 4.7160e-04 - acc: 1.0000
# Epoch 62/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 4.4442e-04 - acc: 1.0000
# Epoch 63/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 4.1948e-04 - acc: 1.0000
# Epoch 64/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.9735e-04 - acc: 1.0000
# Epoch 65/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.7572e-04 - acc: 1.0000
# Epoch 66/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.5422e-04 - acc: 1.0000
# Epoch 67/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.3564e-04 - acc: 1.0000
# Epoch 68/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.1763e-04 - acc: 1.0000
# Epoch 69/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.0129e-04 - acc: 1.0000
# Epoch 70/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.8612e-04 - acc: 1.0000
# Epoch 71/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.7116e-04 - acc: 1.0000
# Epoch 72/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.5768e-04 - acc: 1.0000
# Epoch 73/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.4476e-04 - acc: 1.0000
# Epoch 74/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.3301e-04 - acc: 1.0000
# Epoch 75/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.2171e-04 - acc: 1.0000
# Epoch 76/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.1127e-04 - acc: 1.0000
# Epoch 77/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.0094e-04 - acc: 1.0000
# Epoch 78/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.9161e-04 - acc: 1.0000
# Epoch 79/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.8282e-04 - acc: 1.0000
# Epoch 80/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.7438e-04 - acc: 1.0000
# Epoch 81/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.6634e-04 - acc: 1.0000
# Epoch 82/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.5886e-04 - acc: 1.0000
# Epoch 83/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.5193e-04 - acc: 1.0000
# Epoch 84/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.4510e-04 - acc: 1.0000
# Epoch 85/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.3860e-04 - acc: 1.0000
# Epoch 86/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.3280e-04 - acc: 1.0000
# Epoch 87/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.2710e-04 - acc: 1.0000
# Epoch 88/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.2140e-04 - acc: 1.0000
# Epoch 89/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.1627e-04 - acc: 1.0000
# Epoch 90/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.1141e-04 - acc: 1.0000
# Epoch 91/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.0670e-04 - acc: 1.0000
# Epoch 92/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.0224e-04 - acc: 1.0000
# Epoch 93/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 9.7984e-05 - acc: 1.0000
# Epoch 94/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 9.4062e-05 - acc: 1.0000
# Epoch 95/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 9.0393e-05 - acc: 1.0000
# Epoch 96/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 8.6627e-05 - acc: 1.0000
# Epoch 97/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 8.3099e-05 - acc: 1.0000
# Epoch 98/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 8.0001e-05 - acc: 1.0000
# Epoch 99/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 7.6543e-05 - acc: 1.0000
# Epoch 100/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 7.3457e-05 - acc: 1.0000
# Epoch 101/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 7.0672e-05 - acc: 1.0000
# Epoch 102/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 6.7956e-05 - acc: 1.0000
# Epoch 103/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 6.5304e-05 - acc: 1.0000
# Epoch 104/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 6.2820e-05 - acc: 1.0000
# Epoch 105/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 6.0672e-05 - acc: 1.0000
# Epoch 106/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 5.8213e-05 - acc: 1.0000
# Epoch 107/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 5.5985e-05 - acc: 1.0000
# Epoch 108/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 5.3817e-05 - acc: 1.0000
# Epoch 109/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 5.1934e-05 - acc: 1.0000
# Epoch 110/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 4.9941e-05 - acc: 1.0000
# Epoch 111/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 4.8267e-05 - acc: 1.0000
# Epoch 112/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 4.6558e-05 - acc: 1.0000
# Epoch 113/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 4.4726e-05 - acc: 1.0000
# Epoch 114/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 4.3214e-05 - acc: 1.0000
# Epoch 115/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 4.1688e-05 - acc: 1.0000
# Epoch 116/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 4.0106e-05 - acc: 1.0000
# Epoch 117/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.8781e-05 - acc: 1.0000
# Epoch 118/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.7320e-05 - acc: 1.0000
# Epoch 119/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.6106e-05 - acc: 1.0000
# Epoch 120/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.4896e-05 - acc: 1.0000
# Epoch 121/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.3597e-05 - acc: 1.0000
# Epoch 122/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.2424e-05 - acc: 1.0000
# Epoch 123/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.1294e-05 - acc: 1.0000
# Epoch 124/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 3.0364e-05 - acc: 1.0000
# Epoch 125/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.9360e-05 - acc: 1.0000
# Epoch 126/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.8307e-05 - acc: 1.0000
# Epoch 127/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.7276e-05 - acc: 1.0000
# Epoch 128/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.6416e-05 - acc: 1.0000
# Epoch 129/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.5495e-05 - acc: 1.0000
# Epoch 130/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.4736e-05 - acc: 1.0000
# Epoch 131/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.3921e-05 - acc: 1.0000
# Epoch 132/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.3062e-05 - acc: 1.0000
# Epoch 133/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.2344e-05 - acc: 1.0000
# Epoch 134/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.1592e-05 - acc: 1.0000
# Epoch 135/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.0902e-05 - acc: 1.0000
# Epoch 136/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 2.0239e-05 - acc: 1.0000
# Epoch 137/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.9572e-05 - acc: 1.0000
# Epoch 138/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.8950e-05 - acc: 1.0000
# Epoch 139/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.8399e-05 - acc: 1.0000
# Epoch 140/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.7804e-05 - acc: 1.0000
# Epoch 141/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.7215e-05 - acc: 1.0000
# Epoch 142/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.6663e-05 - acc: 1.0000
# Epoch 143/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.6114e-05 - acc: 1.0000
# Epoch 144/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.5618e-05 - acc: 1.0000
# Epoch 145/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.5137e-05 - acc: 1.0000
# Epoch 146/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.4665e-05 - acc: 1.0000
# Epoch 147/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.4203e-05 - acc: 1.0000
# Epoch 148/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.3793e-05 - acc: 1.0000
# Epoch 149/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.3375e-05 - acc: 1.0000
# Epoch 150/150
# 3650/3650 [==============================] - 11s 3ms/step - loss: 1.2942e-05 - acc: 1.0000

# %%
from random import randint
from keras.preprocessing.sequence import pad_sequences


'''Give seed text as input to generate the whole sequence'''
seed_text="well prince so genoa and lucca are now just family estates of the buonapartes but i warn you if you"

# %%
def generate_seq(model,tokenizer,seq_length,seed_text,n_words):
    '''This function generates the output sequence'''
    
    result = []
    in_text =seed_text
    for i in range(n_words):
        encoded = tokenizer.texts_to_sequences([in_text])[0]
        encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre')
        yhat = model.predict_classes(encoded)
        out_word = ''
        for word,index in tokenizer.word_index.items():
            if index==yhat:
                out_word = word
                break
        in_text+=' ' + out_word
        result.append(word)
    return ' '.join(result)

# %%
'''It will print the next 30 words based on the seed text(testing data)'''

generated = generate_seq(model, tokenizer, seq_length, seed_text, 30)
print(generated)
# Out:
# do n't tell me that this means war if you still try to defend the infamies and horrors perpetrated by that antichrist i really believe he is antichrist i will
